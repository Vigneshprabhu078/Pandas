# %% [markdown]
# **Pandas For Machine Learning**

# %%
import pandas as pd
import numpy as np

# %%
#importing boston dataset from sklearn
from sklearn.datasets import load_diabetes

diabetes=load_diabetes()
type(diabetes)
#print(diabetes)
print(diabetes.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
#pandas DataFrame
diabetes_df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)

# %%
diabetes_df.head(10)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6 -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7  0.063504  0.050680 -0.001895  0.066629  0.090620  0.108914  0.022869
# 8  0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9 -0.070900 -0.044642  0.039062 -0.033213 -0.012577 -0.034508 -0.024993
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# ...

# %%
diabetes_df.shape
# Out:
# (442, 10)

# %%
#Import Csv file to pandas DataFrame
diabetes=pd.read_csv("/content/diabetes.csv")
diabetes.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
#Exporting Dataframe TO CSV
diabetes_df.to_csv("Diabetes_1")

# %%
# create a dataframe with random values
random_df=pd.DataFrame(np.random.rand(10,10,))
random_df.head(3)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.341166  0.941108  0.008008  0.318824  0.058799  0.970990  0.515835
# 1  0.999305  0.095817  0.189633  0.059834  0.522381  0.511293  0.585004
# 2  0.470975  0.057577  0.088194  0.089101  0.066765  0.202431  0.823939
#
#           7         8         9
# 0  0.634167  0.057679  0.112384
# 1  0.763464  0.191901  0.211362
# 2  0.159156  0.294252  0.620441

# %%
random_df.shape
# Out:
# (10, 10)

# %% [markdown]
# **Inspecting DataFrame**

# %%
diabetes_df.shape
# Out:
# (442, 10)

# %%
#first 5 Rows
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
#Last 5 rows
diabetes_df.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064

# %%
#information
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
#finding Number Of Missing Values
diabetes_df.isnull().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
# counting The values based on labels
diabetes_df.value_counts('age').head()
# Out:
# age
#  0.016281    19
#  0.041708    17
#  0.009016    16
# -0.027310    15
# -0.052738    14
# Name: count, dtype: int64

# %%
#group The values based on the mean
diabetes_df.groupby('sex').mean()
# Out:
#                 age       bmi        bp        s1        s2        s3  \
# sex
# -0.044642 -0.007756 -0.003936 -0.010759 -0.001575 -0.006368  0.016923
#  0.050680  0.008805  0.004468  0.012214  0.001788  0.007229 -0.019212
#
#                  s4        s5        s6
# sex
# -0.044642 -0.014826 -0.006693 -0.009291
#  0.050680  0.016832  0.007598  0.010548

# %% [markdown]
# **Statistical measures**

# %%
#count or number of values
diabetes_df.count()
# Out:
# age    442
# sex    442
# bmi    442
# bp     442
# s1     442
# s2     442
# s3     442
# s4     442
# s5     442
# s6     442
# dtype: int64

# %%
diabetes_df.mean() # mean value with column wise
# Out:
# age   -1.444295e-18
# sex    2.543215e-18
# bmi   -2.255925e-16
# bp    -4.854086e-17
# s1    -1.428596e-17
# s2     3.898811e-17
# s3    -6.028360e-18
# s4    -1.788100e-17
# s5     9.243486e-17
# s6     1.351770e-17
# dtype: float64

# %%
diabetes_df.median() # median value with column wise
# Out:
# age    0.005383
# sex   -0.044642
# bmi   -0.007284
# bp    -0.005670
# s1    -0.004321
# s2    -0.003819
# s3    -0.006584
# s4    -0.002592
# s5    -0.001947
# s6    -0.001078
# dtype: float64

# %%
diabetes_df.std() # standard deviation value with column wise
# Out:
# age    0.047619
# sex    0.047619
# bmi    0.047619
# bp     0.047619
# s1     0.047619
# s2     0.047619
# s3     0.047619
# s4     0.047619
# s5     0.047619
# s6     0.047619
# dtype: float64

# %%
diabetes_df.min() # minimum value with column wise
# Out:
# age   -0.107226
# sex   -0.044642
# bmi   -0.090275
# bp    -0.112399
# s1    -0.126781
# s2    -0.115613
# s3    -0.102307
# s4    -0.076395
# s5    -0.126097
# s6    -0.137767
# dtype: float64

# %%
diabetes_df.max() # maximum value with column wise
# Out:
# age    0.110727
# sex    0.050680
# bmi    0.170555
# bp     0.132044
# s1     0.153914
# s2     0.198788
# s3     0.181179
# s4     0.185234
# s5     0.133597
# s6     0.135612
# dtype: float64

# %%
diabetes_df.var() # variance value with column wise
# Out:
# age    0.002268
# sex    0.002268
# bmi    0.002268
# bp     0.002268
# s1     0.002268
# s2     0.002268
# s3     0.002268
# s4     0.002268
# s5     0.002268
# s6     0.002268
# dtype: float64

# %%
diabetes_df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...

# %%
#remove The Index
diabetes_df.drop(index=0,axis=0)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 1   -0.039493 -0.068332 -0.092204
# ...

# %%
#drop a column
diabetes_df.drop(columns='sex',axis=1)
# Out:
#           age       bmi        bp        s1        s2        s3        s4  \
# 0    0.038076  0.061696  0.021872 -0.044223 -0.034821 -0.043401 -0.002592
# 1   -0.001882 -0.051474 -0.026328 -0.008449 -0.019163  0.074412 -0.039493
# 2    0.085299  0.044451 -0.005670 -0.045599 -0.034194 -0.032356 -0.002592
# 3   -0.089063 -0.011595 -0.036656  0.012191  0.024991 -0.036038  0.034309
# 4    0.005383 -0.036385  0.021872  0.003935  0.015596  0.008142 -0.002592
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.019662  0.059744 -0.005697 -0.002566 -0.028674 -0.002592
# 438 -0.005515 -0.015906 -0.067642  0.049341  0.079165 -0.028674  0.034309
# 439  0.041708 -0.015906  0.017293 -0.037344 -0.013840 -0.024993 -0.011080
# 440 -0.045472  0.039062  0.001215  0.016318  0.015283 -0.028674  0.026560
# 441 -0.045472 -0.073030 -0.081413  0.083740  0.027809  0.173816 -0.039493
#
#            s5        s6
# 0    0.019907 -0.017646
# 1   -0.068332 -0.092204
# ...

# %%
#locating a row using the index
diabetes_df.iloc[2]
# Out:
# age    0.085299
# sex    0.050680
# bmi    0.044451
# bp    -0.005670
# s1    -0.045599
# s2    -0.034194
# s3    -0.032356
# s4    -0.002592
# s5     0.002861
# s6    -0.025930
# Name: 2, dtype: float64

# %%
#locating particular column
print(diabetes_df.iloc[:,0])#first Column
# Out:
# 0      0.038076
# 1     -0.001882
# 2      0.085299
# 3     -0.089063
# 4      0.005383
#          ...
# 437    0.041708
# 438   -0.005515
# 439    0.041708
# 440   -0.045472
# 441   -0.045472
# Name: age, Length: 442, dtype: float64

# %% [markdown]
# **Correlation**
#
# 1.Possitive
#
# 2.Negative

# %%
diabetes_df.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex  0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi  0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp   0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1   0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2   0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3  -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4   0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5   0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6   0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
#
#            s4        s5        s6
# age  0.203841  0.270774  0.301731
# sex  0.332115  0.149916  0.208133
# bmi  0.413807  0.446157  0.388680
# ...
